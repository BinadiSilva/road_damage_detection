# %%
import os
os.getcwd()
# Out:
# '/Users/binadisilva/road_damage_detection/code'

# %%
# %cd /Users/binadisilva/road_damage_detection
# Out:
# /Users/binadisilva/road_damage_detection

# %%
# %run code/integrated_code.py
# Out:
# Final integrated processing completed successfully.
# Original frames saved in: /Users/binadisilva/road_damage_detection/Frames
# Enhanced frames saved in: /Users/binadisilva/road_damage_detection/Enhanced
# Segmented masks saved in: /Users/binadisilva/road_damage_detection/Segmented
# Final marked outputs saved in: /Users/binadisilva/road_damage_detection/Final_Output
# Total processed frames: 126

# %%
# %run /Users/binadisilva/road_damage_detection/code/integrated_code.py
# Out:
# Final integrated processing completed successfully.
# Original frames saved in: /Users/binadisilva/road_damage_detection/Frames
# Enhanced frames saved in: /Users/binadisilva/road_damage_detection/Enhanced
# Segmented masks saved in: /Users/binadisilva/road_damage_detection/Segmented
# Final marked outputs saved in: /Users/binadisilva/road_damage_detection/Final_Output
# Total processed frames: 126
